# %%
import pandas as pd

# %%
multi_file_dfs = {
   "mf_5M_10000B_no_comp": pd.read_csv("multi_file_save_summary_5.0keys_10000B_comp-no_csum-yes.csv"),
    "mf_50M_50B_comp": pd.read_csv("multi_file_save_summary_50.0keys_50B_comp-yes_csum-yes.csv"),
    "mf_50M_100B_no_comp": pd.read_csv("multi_file_save_summary_50.0keys_100B_comp-no_csum-yes.csv"),
}

single_file_dfs = {
    "sf_5M_10000B_no_comp": pd.read_csv("one_file_save_summary_5.0keys_10000B_comp-no_csum-yes.csv"),
    "sf_50M_50B_comp": pd.read_csv("one_file_save_summary_50.0keys_50B_comp-yes_csum-yes.csv"),
    "sf_50M_100B_no_comp": pd.read_csv("one_file_save_summary_50.0keys_100B_comp-no_csum-yes.csv"),
}

# %%
multi_file_dfs["mf_5M_10000B_no_comp"]
# Out:
#       keys  value_size  num_threads rdbcompression rdbchecksum  \
# 0  5000000       10000            1             no         yes
# 1  5000000       10000            2             no         yes
# 2  5000000       10000            4             no         yes
# 3  5000000       10000            6             no         yes
# 4  5000000       10000            8             no         yes
# 5  5000000       10000           10             no         yes
#
#    valkey_data_throughput_mb_s  actual_throughput_mb_s  rdb_file_size_bytes  \
# 0                   310.708660                     0.0                    0
# 1                   401.785456                     0.0                    0
# 2                   401.524526                     0.0                    0
# 3                   400.539845                     0.0                    0
# 4                   401.285616                     0.0                    0
# ...

# %%
50100019200/124.662338 * 10**-6
# Out:
# 401.8857660121856

# %%
single_file_dfs["sf_5M_10000B_no_comp"]
# Out:
#       keys  value_size  num_threads rdbcompression rdbchecksum  \
# 0  5000000       10000            1             no         yes
# 1  5000000       10000            2             no         yes
# 2  5000000       10000            4             no         yes
# 3  5000000       10000            6             no         yes
# 4  5000000       10000            8             no         yes
# 5  5000000       10000           10             no         yes
#
#    valkey_data_throughput_mb_s  actual_throughput_mb_s  rdb_file_size_bytes  \
# 0                   305.252701              305.863207          50100000111
# 1                   400.661798              401.463122          50100000111
# 2                   401.699986              402.503387          50100000111
# 3                   401.678702              402.482060          50100000111
# 4                   400.651032              401.452335          50100000111
# ...

# %%
multi_file_dfs["mf_50M_50B_comp"]
# Out:
#        keys  value_size  num_threads rdbcompression rdbchecksum  \
# 0  50000000          50            1            yes         yes
# 1  50000000          50            2            yes         yes
# 2  50000000          50            4            yes         yes
# 3  50000000          50            6            yes         yes
# 4  50000000          50            8            yes         yes
# 5  50000000          50           10            yes         yes
#
#    valkey_data_throughput_mb_s  actual_throughput_mb_s  rdb_file_size_bytes  \
# 0                    44.020616                     0.0                    0
# 1                    97.298050                     0.0                    0
# 2                   131.111438                     0.0                    0
# 3                   139.574506                     0.0                    0
# 4                   133.205506                     0.0                    0
# ...

# %%
3450023936/18.728843 * 10**-6
# Out:
# 184.2091332603941

# %%
single_file_dfs["sf_50M_50B_comp"]
# Out:
#        keys  value_size  num_threads rdbcompression rdbchecksum  \
# 0  50000000          50            1            yes         yes
# 1  50000000          50            2            yes         yes
# 2  50000000          50            4            yes         yes
# 3  50000000          50            6            yes         yes
# 4  50000000          50            8            yes         yes
# 5  50000000          50           10            yes         yes
#
#    valkey_data_throughput_mb_s  actual_throughput_mb_s  rdb_file_size_bytes  \
# 0                    44.354850                     0.0                    0
# 1                    89.286685                     0.0                    0
# 2                   127.364955                     0.0                    0
# 3                   138.304325                     0.0                    0
# 4                   136.518524                     0.0                    0
# ...

# %%
3450003456/18.626553 * 10**-6
# Out:
# 185.2196407998839

# %%
multi_file_dfs["mf_50M_100B_no_comp"]
# Out:
#        keys  value_size  num_threads rdbcompression rdbchecksum  \
# 0  50000000         100            1             no         yes
# 1  50000000         100            2             no         yes
# 2  50000000         100            4             no         yes
# 3  50000000         100            6             no         yes
# 4  50000000         100            8             no         yes
# 5  50000000         100           10             no         yes
#
#    valkey_data_throughput_mb_s  actual_throughput_mb_s  rdb_file_size_bytes  \
# 0                    91.724898                     0.0                    0
# 1                   267.003502                     0.0                    0
# 2                   332.695390                     0.0                    0
# 3                   332.849656                     0.0                    0
# 4                   333.709829                     0.0                    0
# ...

# %%
6000025600/14.962204 * 10**-6
# Out:
# 401.0121503489727

# %%
single_file_dfs["sf_50M_100B_no_comp"]
# Out:
#        keys  value_size  num_threads rdbcompression rdbchecksum  \
# 0  50000000         100            1             no         yes
# 1  50000000         100            2             no         yes
# 2  50000000         100            4             no         yes
# 3  50000000         100            6             no         yes
# 4  50000000         100            8             no         yes
# 5  50000000         100           10             no         yes
#
#    valkey_data_throughput_mb_s  actual_throughput_mb_s  rdb_file_size_bytes  \
# 0                    92.930574                     0.0                    0
# 1                   284.358156                     0.0                    0
# 2                   335.227796                     0.0                    0
# 3                   328.135366                     0.0                    0
# 4                   335.287252                     0.0                    0
# ...

# %%
6000001024/14.928116 * 10**-6
# Out:
# 401.92620582530304
